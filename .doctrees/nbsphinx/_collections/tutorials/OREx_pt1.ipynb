# %% [markdown]
# <!-- SPDX-FileCopyrightText: 2026 Orbital Research Cluster for Celestial Applications (ORCCA) Lab, University of Colorado at Boulder -->
# <!-- SPDX-License-Identifier: ISC -->
# # OSIRIS-REx Tutorial Series Pt 1: Units & Reference Frames
# ---
# Last revised by Z. Ellis on 2026 MAY 26
#
# ## Objectives
# This is the first of a five part tutorial series that aims to walk through a complete orbit determination (OD) scenario within Scarabaeus (SCB) using real data. In part one, you will:
#
# - learn the basics of how SCB represents and operates on units and reference frames
# - prepare a
#
# ## See Also
# - [Part2: Time and SPICE](OREx_pt2.ipynb)
# - [Part3: Creating & Propagating a Spacecraft](OREx_pt3.ipynb)
# - [Part4: Generating Measurements](OREx_pt4.ipynb)
# - [Part5: Running a Filter](OREx_pt5.ipynb)

# %% [markdown]
# ## 1.1 - Dimensions, Units, and ArrayWUnits
